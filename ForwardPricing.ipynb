# %%
import math

# %%
#Calculate Forward Price
def forward_price (S0: float, r: float, T: float):
    "Theoretical forward price under continuous compounding:"
    "F = S0 * exp(r*T)"
    return S0 * math.exp(r * T)

#Detect Arbitrage
def detect_arbitrage (S0,r,T,F_market):
    F_theoretical = forward_price(S0,r,T)

    if F_market > F_theoretical:
        return "Cash-and-carry arbitrage (Forward overpriced)"
    elif F_market < F_theoretical:
        return "Reverse Cash-and-carry (Forward underpriced)"
    else:
        return "No arbitrage"

#Arbitrage Profit
def arbitrage_profit (S0, r, T, F_market, tol=1e-6):
    diff= F_market - F_theoretical

    if abs (diff) <= tol:
        return 0.0, "No arbitrage (Within tolerance)"
    elif diff > tol:
        return diff, "Cash-and-carry (Forward overpriced)"
    else:
        return -diff, "Reverse cash-and-carry (Forward undepriced)"

# %%
if __name__ == "__main__":
    S0 = 100
    r = 0.05
    T = 1
    F_theoretical = forward_price(S0,r,T)
    F_market = 120
    print(F_theoretical)
    print(detect_arbitrage(S0,r,T,F_market))
    profit,label = arbitrage_profit(S0, r, T, F_market)
    print (f"Arbitrage profit at maturity (per unit):",profit)
# Out:
# 105.12710963760242
# Cash-and-carry arbitrage (Forward overpriced)
# Arbitrage profit at maturity (per unit): 14.872890362397584
